# %%
import pandas as pd

data = pd.read_csv("retail_sales_dataset.csv")
data.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
import matplotlib.pyplot as plt

monthly = data.groupby(data['Date'].dt.month)['Total Amount'].sum()

monthly.plot()
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
top_products = data.groupby('Product Category')['Total Amount'].sum().sort_values(ascending=False)

top_products.head()
# Out:
# Product Category
# Electronics    156905
# Clothing       155580
# Beauty         143515
# Name: Total Amount, dtype: int64

# %%
print("INSIGHTS:")
print("1. Sales are highest in month ___")
print("2. Top product category is ___")
print("3. Sales trend shows ___ pattern")
print("4. Some categories perform better than others")
# Out:
# INSIGHTS:
# 1. Sales are highest in month ___
# 2. Top product category is ___
# 3. Sales trend shows ___ pattern
# 4. Some categories perform better than others

# %% [markdown]
# 📊 Insights
# Sales peak observed in (may).
# (electronics) generates highest revenue.
# Sales show increasing/decreasing trend.
# Certain categories dominate overall sales
